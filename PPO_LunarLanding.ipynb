# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from dense_scripts.utils import record_videos
model = train_ppo()
device = "cuda"
env_id = "LunarLander-v3"
model.to(device)
record_videos(model, env_id, video_dir=f"videos/PPO", episodes=6, device=device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from dense_scripts.utils import record_videos
# ----> 2 model = train_ppo()
#       3 device = "cuda"
#       4 env_id = "LunarLander-v3"
#
# NameError: name 'train_ppo' is not defined

# %%
from dense_scripts.PPO import PPOTrainer, PPOConfig
from dense_scripts.utils.policies import SimpleActorCriticPolicy

cfg = PPOConfig(
    env_id="LunarLander-v3",
    G=24, T=1024,
    epochs=8, minibatches=32,
    gamma=0.99, lam=0.95,
    lr=3e-4,
    vf_coef=0.5, ent_coef=0.01,
    target_kl=0.015,
    n_workers=24,
    log_dir="./runs/PPO"
)


pi = SimpleActorCriticPolicy(obs_dim=8, act_dim=4)

trainer = PPOTrainer(policy=pi, config=cfg, device="cpu")

pi_star, v_star = trainer.train(
    iters=50,
    video_dir="videos/PPO",
    video_fps=30,
    video_format="mp4",
    video_episodes=6
)

# %%
import torch
# PPO needs an Actor-Critic policy (or any policy with .dist() and .value() methods)
from dense_scripts.utils import SimpleActorCriticPolicy 
from dense_scripts.PPO import PPOTrainer, PPOConfig
from dense_scripts.utils import DenseLunarLander

# 1. Initialize environments
env_train = DenseLunarLander(randomize_angle=True, randomize_pos=True)
env_eval = DenseLunarLander(randomize_angle=False, randomize_pos=False)

# 2. Initialize the Policy
# The PPOTrainer will automatically create its own ValueNet, 
# but it's cleaner to use a combined ActorCriticPolicy.
policy = SimpleActorCriticPolicy(env_train.observation_space.shape[0], env_train.action_space.n)

# 3. Configure the Trainer
cfg = PPOConfig(
    env=env_train,
    G=32,
    T=1024,
    gamma=0.99,
    lam=0.95,
    log_dir="./runs/PPO_Lander"
)

# 4. Initialize the Trainer
trainer = PPOTrainer(policy, cfg, device="cpu") # or "cuda"

# 5. Run Training
trainer.train(
    iters=300,
    eval_env=env_eval,
    eval_interval=30,
    eval_episodes=100,
    video_dir="videos/PPO_Lander",
    video_episodes=10
)
# Out:
# 📝 Saved hyperparameters to runs/PPO_Lander/ppo_22h27_09112025/ppo_22h27_09112025.txt
# PPO (22h27_09112025):   3%|█▉                                                       | 1/30 [00:03<01:33,  3.21s/it, KL=0.008, avgR=-187, it_s=3.21]
# Iter 000 | avgR -187.5 ±104.7 | KL~ 0.0080 | clipfrac 0.078 | Lπ -0.0053 Lv 684.35 H 1.381 | steps 32768 | 3.21s
# PPO (22h27_09112025):   7%|███▊                                                     | 2/30 [00:06<01:32,  3.32s/it, KL=0.009, avgR=-151, it_s=3.40]
# Iter 001 | avgR -151.2 ±93.0 | KL~ 0.0092 | clipfrac 0.076 | Lπ -0.0080 Lv 443.31 H 1.369 | steps 65536 | 3.40s
# PPO (22h27_09112025):  10%|█████▋                                                   | 3/30 [00:09<01:29,  3.32s/it, KL=0.010, avgR=-122, it_s=3.32]
# Iter 002 | avgR -122.1 ±65.0 | KL~ 0.0100 | clipfrac 0.122 | Lπ -0.0076 Lv 236.44 H 1.345 | steps 98304 | 3.32s
# PPO (22h27_09112025):  13%|███████▌                                                 | 4/30 [00:13<01:25,  3.28s/it, KL=0.009, avgR=-115, it_s=3.21]
# Iter 003 | avgR -115.4 ±66.7 | KL~ 0.0086 | clipfrac 0.065 | Lπ -0.0073 Lv 197.12 H 1.319 | steps 131072 | 3.21s
# PPO (22h27_09112025):  17%|█████████▋                                                | 5/30 [00:16<01:18,  3.16s/it, KL=0.010, avgR=-92, it_s=2.94]
# Iter 004 | avgR -91.6 ±53.5 | KL~ 0.0099 | clipfrac 0.109 | Lπ -0.0091 Lv 139.31 H 1.260 | steps 163840 | 2.94s
# PPO (22h27_09112025):  20%|███████████▌                                              | 6/30 [00:18<01:11,  3.00s/it, KL=0.011, avgR=-77, it_s=2.68]
# Iter 005 | avgR -76.8 ±60.1 | KL~ 0.0109 | clipfrac 0.123 | Lπ -0.0100 Lv 134.11 H 1.194 | steps 196608 | 2.68s
# PPO (22h27_09112025):  23%|█████████████▌                                            | 7/30 [00:21<01:08,  2.98s/it, KL=0.008, avgR=-76, it_s=2.93]
# Iter 006 | avgR -76.2 ±66.1 | KL~ 0.0080 | clipfrac 0.070 | Lπ -0.0068 Lv 132.34 H 1.148 | steps 229376 | 2.93s
# PPO (22h27_09112025):  27%|███████████████▍                                          | 8/30 [00:24<01:07,  3.05s/it, KL=0.008, avgR=-59, it_s=3.22]
# Iter 007 | avgR -59.2 ±64.9 | KL~ 0.0079 | clipfrac 0.073 | Lπ -0.0070 Lv 135.38 H 1.106 | steps 262144 | 3.22s
# PPO (22h27_09112025):  30%|█████████████████▍                                        | 9/30 [00:28<01:04,  3.07s/it, KL=0.008, avgR=-72, it_s=3.10]
# Iter 008 | avgR -71.9 ±68.3 | KL~ 0.0080 | clipfrac 0.084 | Lπ -0.0066 Lv 122.80 H 1.057 | steps 294912 | 3.10s
# PPO (22h27_09112025):  33%|███████████████████                                      | 10/30 [00:31<01:02,  3.13s/it, KL=0.005, avgR=-74, it_s=3.25]
# Iter 009 | avgR -74.2 ±68.1 | KL~ 0.0053 | clipfrac 0.054 | Lπ -0.0057 Lv 90.28 H 1.064 | steps 327680 | 3.25s
# PPO (22h27_09112025):  37%|████████████████████▉                                    | 11/30 [00:34<00:58,  3.08s/it, KL=0.006, avgR=-61, it_s=2.96]
# Iter 010 | avgR -61.4 ±51.6 | KL~ 0.0058 | clipfrac 0.073 | Lπ -0.0055 Lv 61.42 H 1.044 | steps 360448 | 2.96s
# PPO (22h27_09112025):  40%|██████████████████████▊                                  | 12/30 [00:37<00:55,  3.11s/it, KL=0.006, avgR=-52, it_s=3.19]
# Iter 011 | avgR -51.8 ±40.7 | KL~ 0.0057 | clipfrac 0.072 | Lπ -0.0064 Lv 36.20 H 1.078 | steps 393216 | 3.19s
# PPO (22h27_09112025):  43%|████████████████████████▋                                | 13/30 [00:40<00:53,  3.13s/it, KL=0.004, avgR=-61, it_s=3.18]
# Iter 012 | avgR -60.8 ±62.8 | KL~ 0.0045 | clipfrac 0.058 | Lπ -0.0038 Lv 38.63 H 1.085 | steps 425984 | 3.18s
# PPO (22h27_09112025):  47%|██████████████████████████▌                              | 14/30 [00:43<00:50,  3.17s/it, KL=0.006, avgR=-32, it_s=3.26]
# Iter 013 | avgR -31.7 ±33.6 | KL~ 0.0061 | clipfrac 0.073 | Lπ -0.0037 Lv 28.31 H 1.079 | steps 458752 | 3.26s
# PPO (22h27_09112025):  50%|████████████████████████████▌                            | 15/30 [00:47<00:47,  3.20s/it, KL=0.005, avgR=-21, it_s=3.27]
# Iter 014 | avgR -21.4 ±21.7 | KL~ 0.0052 | clipfrac 0.061 | Lπ -0.0036 Lv 21.11 H 1.039 | steps 491520 | 3.27s
# PPO (22h27_09112025):  53%|██████████████████████████████▍                          | 16/30 [00:49<00:42,  3.05s/it, KL=0.006, avgR=-11, it_s=2.71]
# Iter 015 | avgR -10.6 ±70.0 | KL~ 0.0057 | clipfrac 0.058 | Lπ -0.0034 Lv 18.54 H 1.051 | steps 524288 | 2.71s
# PPO (22h27_09112025):  57%|█████████████████████████████████▍                         | 17/30 [00:52<00:39,  3.02s/it, KL=0.006, avgR=9, it_s=2.95]
# Iter 016 | avgR 8.9 ±88.1 | KL~ 0.0058 | clipfrac 0.054 | Lπ -0.0025 Lv 12.61 H 1.049 | steps 557056 | 2.95s
# PPO (22h27_09112025):  60%|██████████████████████████████████▏                      | 18/30 [00:55<00:35,  2.93s/it, KL=0.007, avgR=-31, it_s=2.71]
# Iter 017 | avgR -30.8 ±15.9 | KL~ 0.0069 | clipfrac 0.082 | Lπ -0.0031 Lv 12.05 H 1.079 | steps 589824 | 2.71s
# PPO (22h27_09112025):  63%|████████████████████████████████████▋                     | 19/30 [00:58<00:33,  3.03s/it, KL=0.007, avgR=65, it_s=3.27]
# Iter 018 | avgR 64.5 ±140.4 | KL~ 0.0074 | clipfrac 0.077 | Lπ -0.0038 Lv 15.94 H 1.030 | steps 622592 | 3.27s
# PPO (22h27_09112025):  67%|██████████████████████████████████████▋                   | 20/30 [01:01<00:29,  2.94s/it, KL=0.005, avgR=45, it_s=2.71]
# Iter 019 | avgR 44.6 ±112.8 | KL~ 0.0046 | clipfrac 0.041 | Lπ -0.0021 Lv 18.78 H 1.005 | steps 655360 | 2.71s
# PPO (22h27_09112025):  70%|███████████████████████████████████████▉                 | 21/30 [01:04<00:27,  3.01s/it, KL=0.005, avgR=109, it_s=3.19]
# Iter 020 | avgR 109.3 ±112.2 | KL~ 0.0051 | clipfrac 0.048 | Lπ -0.0024 Lv 26.09 H 0.982 | steps 688128 | 3.19s
# PPO (22h27_09112025):  73%|██████████████████████████████████████████▌               | 22/30 [01:07<00:24,  3.04s/it, KL=0.005, avgR=53, it_s=3.09]
# Iter 021 | avgR 52.8 ±106.6 | KL~ 0.0047 | clipfrac 0.037 | Lπ -0.0019 Lv 27.26 H 0.986 | steps 720896 | 3.09s
# PPO (22h27_09112025):  77%|████████████████████████████████████████████▍             | 23/30 [01:10<00:21,  3.08s/it, KL=0.006, avgR=79, it_s=3.18]
# Iter 022 | avgR 79.0 ±103.6 | KL~ 0.0055 | clipfrac 0.058 | Lπ -0.0018 Lv 12.71 H 0.981 | steps 753664 | 3.18s
# PPO (22h27_09112025):  80%|█████████████████████████████████████████████▌           | 24/30 [01:14<00:18,  3.08s/it, KL=0.005, avgR=118, it_s=3.06]
# Iter 023 | avgR 117.9 ±114.5 | KL~ 0.0045 | clipfrac 0.038 | Lπ -0.0021 Lv 12.81 H 0.988 | steps 786432 | 3.06s
# PPO (22h27_09112025):  83%|████████████████████████████████████████████████▎         | 25/30 [01:16<00:15,  3.03s/it, KL=0.004, avgR=51, it_s=2.92]
# Iter 024 | avgR 51.5 ±96.1 | KL~ 0.0036 | clipfrac 0.029 | Lπ -0.0017 Lv 17.89 H 0.987 | steps 819200 | 2.92s
# PPO (22h27_09112025):  87%|█████████████████████████████████████████████████▍       | 26/30 [01:19<00:11,  2.94s/it, KL=0.006, avgR=172, it_s=2.74]
# Iter 025 | avgR 172.2 ±68.8 | KL~ 0.0056 | clipfrac 0.056 | Lπ -0.0023 Lv 12.47 H 0.988 | steps 851968 | 2.74s
# PPO (22h27_09112025):  90%|███████████████████████████████████████████████████▎     | 27/30 [01:23<00:09,  3.06s/it, KL=0.006, avgR=149, it_s=3.32]
# Iter 026 | avgR 148.9 ±95.6 | KL~ 0.0064 | clipfrac 0.059 | Lπ -0.0019 Lv 18.29 H 0.951 | steps 884736 | 3.32s
# PPO (22h27_09112025):  93%|█████████████████████████████████████████████████████▏   | 28/30 [01:25<00:05,  2.95s/it, KL=0.007, avgR=102, it_s=2.70]
# Iter 027 | avgR 102.2 ±106.4 | KL~ 0.0075 | clipfrac 0.107 | Lπ -0.0013 Lv 8.77 H 0.992 | steps 917504 | 2.70s
# PPO (22h27_09112025):  97%|███████████████████████████████████████████████████████  | 29/30 [01:29<00:03,  3.07s/it, KL=0.004, avgR=102, it_s=3.34]
# Iter 028 | avgR 102.5 ±110.9 | KL~ 0.0040 | clipfrac 0.031 | Lπ -0.0011 Lv 14.43 H 0.957 | steps 950272 | 3.34s
# PPO (22h27_09112025):  97%|███████████████████████████████████████████████████████  | 29/30 [01:31<00:03,  3.07s/it, KL=0.003, avgR=128, it_s=2.73]
# Iter 029 | avgR 127.7 ±106.3 | KL~ 0.0034 | clipfrac 0.030 | Lπ -0.0011 Lv 21.48 H 0.947 | steps 983040 | 2.73s
#
# 🎯 Evaluating SimpleActorCriticPolicy for 100 episodes using 24 processes...
# PPO (22h27_09112025): 100%|█████████████████████████████████████████████████████████| 30/30 [01:34<00:00,  3.13s/it, KL=0.003, avgR=128, it_s=2.73]
#    ✓ Reward: 119.71 ± 72.47
#    ✓ Success Rate: 2.00%
#    ✓ Legs Touching: 0.63
#    ✓ Mean Velocity: 0.047
#    ✓ Distance from Pad: 0.377
# ✅ PPO training complete — logs at runs/PPO_Lander/ppo_22h27_09112025
# 🎥 Recording PPO evaluation videos to videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025
# 🎥 Recording 10 episodes from DenseLunarLander...
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep01_R203.8.mp4 | Reward: 203.8
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep02_R237.2.mp4 | Reward: 237.2
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep03_R228.5.mp4 | Reward: 228.5
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep04_R239.0.mp4 | Reward: 239.0
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep05_R6.3.mp4 | Reward: 6.3
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep06_R-72.3.mp4 | Reward: -72.3
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep07_R200.5.mp4 | Reward: 200.5
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep08_R251.0.mp4 | Reward: 251.0
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep09_R198.1.mp4 | Reward: 198.1
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Saved MP4 video: videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/DenseLunarLander_ep10_R217.4.mp4 | Reward: 217.4
# 📝 Saved video parameters to videos/PPO_Lander/ppo_G32_γ0.99_22h27_09112025/ppo_22h27_09112025.txt
# (SimpleActorCriticPolicy(
#    (pi): Sequential(
#      (0): Linear(in_features=8, out_features=128, bias=True)
#      (1): Tanh()
#      (2): Linear(in_features=128, out_features=128, bias=True)
#      (3): Tanh()
#      (4): Linear(in_features=128, out_features=4, bias=True)
#    )
#    (v): Sequential(
#      (0): Linear(in_features=8, out_features=128, bias=True)
#      (1): Tanh()
#      (2): Linear(in_features=128, out_features=128, bias=True)
#      (3): Tanh()
#      (4): Linear(in_features=128, out_features=1, bias=True)
#    )
#  ),
#  ValueNet(
#    (net): Sequential(
#      (0): Linear(in_features=8, out_features=128, bias=True)
#      (1): Tanh()
#      (2): Linear(in_features=128, out_features=128, bias=True)
#      (3): Tanh()
#      (4): Linear(in_features=128, out_features=1, bias=True)
#    )
#  ))
